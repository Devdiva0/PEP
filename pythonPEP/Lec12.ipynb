# %% [markdown]
# <h2>Tuples</h2>

# %%
t=(1,2,5,3,2,5,23,56,9)
t
# Out:
# (1, 2, 5, 3, 2, 5, 23, 56, 9)

# %%
sorted(t) # gives new list
# Out:
# [1, 2, 2, 3, 5, 5, 9, 23, 56]

# %%
del(t) # remove the tuple

# %% [markdown]
# <h2>Sets
