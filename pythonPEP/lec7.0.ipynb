# %% [markdown]
# <h3>-------------------------------------functions------------------------------------------------------

# %%
def greet():
    print("good Day, Everyone")

greet()
# Out:
# good Day, Everyone

# %%
def add(a,b):
    return a + b

n=5
m=3
print(add(n,m))
# Out:
# 8

# %%
def multi(a,b):
    return a * b

n=5
m=3
add(n,m)
multi(n,m)
# Out:
# 15

# %%
def nothing(n,m):
    return
nothing(n,m)
