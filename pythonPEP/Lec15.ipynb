# %%
##File handling

##Need of file :- to store the data permanenetly

##opening a file 
  
##common modes :-
##r -> read
##w -> write (overwrite)
##a -> append
##x -> create a new file
##r+, w+, a+ -> read and write

##writing to a file

# %%
 ##Creating a file

with open("Day-15_file.txt", "x") as file:
    print("File created successfully")
# Out:
# File created successfully

# %%
##wriring to a file

with open("Day-15_file.txt", "w") as file:
    file.write("Anmol, 101, 6\n")
    file.write("Aman, 102, 5\n")
    print("Data written succesfully")
# Out:
# Data written succesfully

# %%
##reading a file

with open("Day-15_file.txt", "r") as file:
    print(file.read())
    print("Data read")
# Out:
# Anmol, 101, 6
# Aman, 102, 5
#
# Data read

# %%
##data appending in a file

with open("Day-15_file.txt", "a") as file:
    file.write("Amit, 104, 9\n")
    print("Data appended")
# Out:
# Data appended

# %%
##File reading

with open("Day-15_file.txt", "r") as file:
    print(file.read())
# Out:
# Anmol, 101, 6
# Aman, 102, 5
# Amit, 104, 9

# %%
##tell and seek

with open("Day-15_file.txt", "r") as file:
    file.tell()
    print(file.read())
    file.seek(8)
    print(file.read())
# Out:
# Anmol, 101, 6
# Aman, 102, 5
# Amit, 104, 9
#
# 01, 6
# Aman, 102, 5
# Amit, 104, 9

# %%
##create a file and write introductiion

with open("Day-15_student.txt", "w") as file:
    print("file created")
# Out:
# file created

# %%
with open("Day-15_student.txt", "w") as file:
    file.write("Name : Anmol Kumar\n")
    file.write("Course : B.Tech(CSE)\n")
    file.write("Sem : 7th\n")
    file.write("Hometown : Patna\n")

# %%
with open("Day-15_student.txt", "r") as file:
    print(file.read())
# Out:
# Name : Anmol Kumar
# Course : B.Tech(CSE)
# Sem : 7th
# Hometown : Patna

# %%
with open("Day-15_student.txt", "a") as file:
    file.write("State : Bihar\n")
    print("Data appended")
# Out:
# Data appended

# %%
##count number of lines
count = 0
with open("Day-15_student.txt", "r") as file:
    for line in file:
        count = count + 1
print(count)
# Out:
# 5

# %%
##count number of words

count = 0
with open("Day-15_student.txt", "r") as file:
    for line in file:
        word = line.split()
        count += len(word)
print(count)
# Out:
# 16

# %%
##Search a word

search = "Anmol"
with open("Day-15_student.txt", "r") as file:
    for line in file:
        word = line.split()
        if search in word:
            found = True
            break
if found:
    print("Word exists")
else:
    print("Word does not exist")
# Out:
# Word exists

# %%
##copy one file to another


with open("Day-15_student.txt", "r") as source:
    content = source.read()

with open("Day-15_student_copy.txt", "w") as destination:
    destination.write(content)

print("File copied successfully.")
# Out:
# File copied successfully.

# %%
##convert file content to uppercase

with open("Day-15_student.txt", "r") as file:
    for line in file:
        print(line.upper(), end="")
# Out:
# NAME : ANMOL KUMAR
# COURSE : B.TECH(CSE)
# SEM : 7TH
# HOMETOWN : PATNA
# STATE : BIHAR

# %%
##Read alternate lines

count = 0

with open("Day-15_student.txt", "r") as file:
    for line in file:
        if count % 2 == 0:
            print(line, end="")
        count += 1
# Out:
# Name : Anmol Kumar
# Sem : 7th
# State : Bihar
