# %%
# shows list provided. Display first , last, top3, last3, alternate shows, reverse using slicing.
shows=["deva","RRR","KGF","KGF2","NANA","Leo","Animal","Maa-Bahen"]
print(shows[0])
print(shows[len(shows)-1])
print(shows[:3])
print(shows[-3:])
print(shows[::2])
print(shows[::-1])
# Out:
# deva
# Maa-Bahen
# ['deva', 'RRR', 'KGF']
# ['Leo', 'Animal', 'Maa-Bahen']
# ['deva', 'KGF', 'NANA', 'Animal']
# ['Maa-Bahen', 'Animal', 'Leo', 'NANA', 'KGF2', 'KGF', 'RRR', 'deva']

# %%
# heart rates list. Print pateints with heart rate>100 BPM and count them.
hr=[44,77,755,87,56,101,110,240]
count=0
for i in hr:
    if i>100:
        print(i)
        count+=1

print(count)
# Out:
# 755
# 101
# 110
# 240
# 4

# %%
# salary list. Display hightest, lowest, total and average salary.
salary=[34,56,21,32,22,65,85,22,12]
print(max(salary))
print(min(salary))
print((sum(salary))/len(salary))
print(sum(salary))
# Out:
# 85
# 12
# 38.77777777777778
# 349

# %%
#Take employee ID as input. Print Access Granted or Access Denied 
emp=[101,102,103,104,105,106,107]
inemp=int(input())
if inemp in emp:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
#  109
# Access Denied

# %%
# predict output of aliasing ex., explain why it happen and how to avoid it
a=[1,2,3]
b=a
print(a) #1,2,3
print(b) #1,2,3

b.append(40)

print(a)
print(b)
#Why did a change?
#Because a and b are pointing to the same list.
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3, 40]
# [1, 2, 3, 40]
